# %%
# Import necessary packages
import pandas as pd
# !pip install fbprophet
from fbprophet import Prophet
# Out:
# ...
#      ---------------------------------------- 64.0/64.0 kB 3.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 2.8/2.8 MB 19.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 47.9/47.9 kB 2.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.0/1.0 MB 21.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 5.8/5.8 MB 21.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 1.4/1.4 MB 29.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 91.8/91.8 kB 5.1 MB/s eta 0:00:00
# ...
#      ------------------------------------- 370.7/370.7 kB 24.0 MB/s eta 0:00:00
# ...
#      -------------------------------------- 411.7/411.7 kB 8.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
# ...

# %%
# Load dataset
df = pd.read_csv("C:\HAMOYE\Time series\household_power_consumption.txt",sep=';')
# Out:
# C:\Users\bidem\AppData\Local\Temp\ipykernel_7600\3177570129.py:2: DtypeWarning: Columns (2,3,4,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("C:\HAMOYE\Time series\household_power_consumption.txt",sep=';')

# %%
df.head()
# Out:
#          Date      Time Global_active_power Global_reactive_power  Voltage  \
# 0  16/12/2006  17:24:00               4.216                 0.418  234.840
# 1  16/12/2006  17:25:00               5.360                 0.436  233.630
# 2  16/12/2006  17:26:00               5.374                 0.498  233.290
# 3  16/12/2006  17:27:00               5.388                 0.502  233.740
# 4  16/12/2006  17:28:00               3.666                 0.528  235.680
#
#   Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3
# 0           18.400          0.000          1.000            17.0
# 1           23.000          0.000          1.000            16.0
# 2           23.000          0.000          2.000            17.0
# 3           23.000          0.000          1.000            17.0
# 4           15.800          0.000          1.000            17.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075259 entries, 0 to 2075258
# Data columns (total 9 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Date                   object
#  1   Time                   object
#  2   Global_active_power    object
#  3   Global_reactive_power  object
#  4   Voltage                object
#  5   Global_intensity       object
#  6   Sub_metering_1         object
#  7   Sub_metering_2         object
#  8   Sub_metering_3         float64
# dtypes: float64(1), object(8)
# memory usage: 142.5+ MB

# %%
df.isnull().sum()
# Out:
# Date                         0
# Time                         0
# Global_active_power          0
# Global_reactive_power        0
# Voltage                      0
# Global_intensity             0
# Sub_metering_1               0
# Sub_metering_2               0
# Sub_metering_3           25979
# dtype: int64

# %%
df.isnull().values.any()
# Out:
# True

# %%
df1 = df.copy()

# %%
#df1['DateTime'] = pd.to_datetime(df1['Date'] + ' ' + df1['Time'])

#df1 = df1.set_index('DateTime')

df1['DateTime'] = pd.to_datetime(df1['Date'] + ' ' + df1['Time'], dayfirst=True)
df1 = df1.set_index('DateTime')

# %%
df1.head()
# Out:
#                            Date      Time Global_active_power  \
# DateTime
# 2006-12-16 17:24:00  16/12/2006  17:24:00               4.216
# 2006-12-16 17:25:00  16/12/2006  17:25:00               5.360
# 2006-12-16 17:26:00  16/12/2006  17:26:00               5.374
# 2006-12-16 17:27:00  16/12/2006  17:27:00               5.388
# 2006-12-16 17:28:00  16/12/2006  17:28:00               3.666
#
#                     Global_reactive_power  Voltage Global_intensity  \
# DateTime
# 2006-12-16 17:24:00                 0.418  234.840           18.400
# 2006-12-16 17:25:00                 0.436  233.630           23.000
# 2006-12-16 17:26:00                 0.498  233.290           23.000
# 2006-12-16 17:27:00                 0.502  233.740           23.000
# 2006-12-16 17:28:00                 0.528  235.680           15.800
#
#                     Sub_metering_1 Sub_metering_2  Sub_metering_3
# DateTime
# 2006-12-16 17:24:00          0.000          1.000            17.0
# ...

# %%
df1
# Out:
#                            Date      Time Global_active_power  \
# DateTime
# 2006-12-16 17:24:00  16/12/2006  17:24:00               4.216
# 2006-12-16 17:25:00  16/12/2006  17:25:00               5.360
# 2006-12-16 17:26:00  16/12/2006  17:26:00               5.374
# 2006-12-16 17:27:00  16/12/2006  17:27:00               5.388
# 2006-12-16 17:28:00  16/12/2006  17:28:00               3.666
# ...                         ...       ...                 ...
# 2010-11-26 20:58:00  26/11/2010  20:58:00               0.946
# 2010-11-26 20:59:00  26/11/2010  20:59:00               0.944
# 2010-11-26 21:00:00  26/11/2010  21:00:00               0.938
# 2010-11-26 21:01:00  26/11/2010  21:01:00               0.934
# 2010-11-26 21:02:00  26/11/2010  21:02:00               0.932
#
#                     Global_reactive_power  Voltage Global_intensity  \
# DateTime
# 2006-12-16 17:24:00                 0.418  234.840           18.400
# ...

# %%
df1.columns
# Out:
# Index(['Date', 'Time', 'Global_active_power', 'Global_reactive_power',
#        'Voltage', 'Global_intensity', 'Sub_metering_1', 'Sub_metering_2',
#        'Sub_metering_3'],
#       dtype='object')

# %%
#df1['DateTime'] = pd.to_datetime(df1['Date'] + '' + df1["Time"])
df1['DateTime'] = pd.to_datetime(df1['Date'] + ' ' + df1['Time'], format='%d/%m/%Y %H:%M:%S')
df1.set_index("DateTime", inplace=True)
#df1 = df1.resample('D').sum().reset_index()
resampled_df = df1.resample('D')['Global_active_power'].sum().reset_index()

#df1['Global_active_power'] = df1.resample('D')['Global_active_power'].sum().reset_index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 5
#       3 df1.set_index("DateTime", inplace=True)
#       4 #df1 = df1.resample('D').sum().reset_index()
# ----> 5 resampled_df = df1.resample('D')['Global_active_power'].sum().reset_index()
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:3146, in GroupBy.sum(self, numeric_only, min_count, engine, engine_kwargs)
#    3141 else:
#    3142     # If we are grouping on categoricals we want unobserved categories to
#    3143     # return zero, rather than the default of NaN which the reindexing in
#    3144     # _agg_general() returns. GH #31422
#    3145     with com.temp_setattr(self, "observed", True):
# -> 3146         result = self._agg_general(
#    3147             numeric_only=numeric_only,
#    3148             min_count=min_count,
#    3149             alias="sum",
# ...
